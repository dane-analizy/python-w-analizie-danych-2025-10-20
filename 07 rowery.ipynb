# %% [markdown]
# ### Najpierw ściągnij plik http://prokulski.science/temp/test/veturilo.zip i wypakuj do folderu "rowery"
#
# ### Co tu się będzie działo?
#
# 1. wczytamy wszystkie JSONy po kolei
# 2. zrobimy z nich wielki data frame
# 3. i zapiszemy do np. CSV

# %%
import pandas as pd
import json
from pathlib import Path

# %%
# przygotowanie listy wszystkich plików

folder_glowny = Path("rowery/veturilo/2025-10-20")

# %%
def przetworz_plik_json(plik):
    # wczytujemy zawartość pliku
    dane_json = plik.read_text(encoding='utf-8')

    # parsujemy zawartość jako json
    dane = json.loads(dane_json)

    # dla każdej stacji z danych z pliku...
    dane_stacje = []
    for station in dane['network']['stations']:
        # usun klucz "extra"
        station.pop('extra')
        # dodaj do listy rekordów
        dane_stacje.append(station)

    # z całej listy zrób data frame
    dane_stacje_df = pd.DataFrame(dane_stacje)

    # oddaj poza funkcję
    return dane_stacje_df

# %%
lista_df = []
for plik in folder_glowny.glob("*.json"): # wyszukaj wszytkie pliki z rozszerzeniem json
    temp_df = przetworz_plik_json(plik) # przetwórz każdy z nich
    lista_df.append(temp_df)

# %%
len(lista_df)

# %%
lista_df[0]

# %%
# sklejanie tabel ze sobą

df1 = pd.DataFrame([{'imie': 'Maria',
  'nazwisko': 'Iksińska',
  'wiek': 45,
  'stan_cywilny': 'panna'},
 {'imie': 'Zofia', 'nazwisko': 'Jakaś', 'wiek': 18}])


df2 = pd.DataFrame([{'imie': 'Jan', 'nazwisko': 'Kowalski', 'wiek': 50, 'zawod': 'miłosny'},
 {'imie': 'Anna', 'nazwisko': 'Nowak', 'wiek': 30}])

# %%
sklejone_df = pd.concat( [df2, df1]  , axis=0 ) 
sklejone_df

# %%
sklejone_df.loc[1, :]

# %%
sklejone_df.reset_index(drop=True)

# %%
rowery_df = pd.concat( lista_df, axis=0)
rowery_df = rowery_df.reset_index(drop=True)
rowery_df
# Out:
#                                       id                            name  \
# 0       005de3bbdc044ed97ea20d32ea6401be   al. Niepodległości - Batorego
# 1       013e8c1f7b4782baa326a337d2b00394           Marymoncka - Dewajtis
# 2       029c42156011a06c59bc24773c914cba    Metro Centrum Nauki Kopernik
# 3       02c9feac733886f5bdef0fe682da4b32  Darwina - Nusbauma-Hilarowicza
# 4       037fadcd3c17b99a1cbc687d1d04274d    al. Jerozolimskie - Lindleya
# ...                                  ...                             ...
# 495355  fda32f025901aa9743b1596d43969ab3      al. Jerozolimskie - Krucza
# 495356  feb31a4e8466caf11d6a16addc0b11e1     Rembielińska - Wyszogrodzka
# 495357  ff8fbef897530b901229c204eb46b8a1                 Plac Grzybowski
# 495358  ff90e71b117a22c29d636bdfff8b1bbe      Sosnkowskiego - OSiR Ursus
# 495359  fffeecd35a623278f18627b396a6fde9             Pętla Podskarbińska
#
#          latitude  longitude                          timestamp  free_bikes  \
# 0       52.210833  21.007851  2025-10-19T23:57:33.672212+00:00Z          21
# 1       52.290173  20.950370  2025-10-19T23:57:33.667969+00:00Z          13
# 2       52.239358  21.031136  2025-10-19T23:57:33.697936+00:00Z          27
# 3       52.264210  21.026180  2025-10-19T23:57:33.696712+00:00Z          11
# 4       52.226220  20.996172  2025-10-19T23:57:33.670933+00:00Z          10
# ...           ...        ...                                ...         ...
# 495355  52.231056  21.016738  2025-10-20T23:57:39.393682+00:00Z           1
# 495356  52.288592  21.031009  2025-10-20T23:57:39.396460+00:00Z          23
# 495357  52.235858  21.003731  2025-10-20T23:57:39.345487+00:00Z           4
# 495358  52.186994  20.890648  2025-10-20T23:57:39.395220+00:00Z          12
# 495359  52.254189  21.073601  2025-10-20T23:57:39.344900+00:00Z          15
#
#         empty_slots
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 495355            7
# 495356            0
# 495357            8
# 495358            0
# 495359            0
#
# [495360 rows x 7 columns]

# %%
dt = pd.to_datetime("2025-10-20T23:57:39.344900")
dt

# %%
len("2025-10-20T23:57:39.344900")

# %%
s = "2025-10-20T23:57:39.344900+00:00Z"
pd.to_datetime(s[:26])

# %%
def zmien_date(s):
    dt = pd.to_datetime(s[:26])
    return dt

# %%
rowery_df['datetime'] = rowery_df['timestamp'].apply(lambda s: zmien_date(s))

# %%
rowery_df['suma_long_lat'] = rowery_df['latitude'] + rowery_df['longitude'] * 6
rowery_df
# Out:
#                                       id                            name  \
# 0       005de3bbdc044ed97ea20d32ea6401be   al. Niepodległości - Batorego
# 1       013e8c1f7b4782baa326a337d2b00394           Marymoncka - Dewajtis
# 2       029c42156011a06c59bc24773c914cba    Metro Centrum Nauki Kopernik
# 3       02c9feac733886f5bdef0fe682da4b32  Darwina - Nusbauma-Hilarowicza
# 4       037fadcd3c17b99a1cbc687d1d04274d    al. Jerozolimskie - Lindleya
# ...                                  ...                             ...
# 495355  fda32f025901aa9743b1596d43969ab3      al. Jerozolimskie - Krucza
# 495356  feb31a4e8466caf11d6a16addc0b11e1     Rembielińska - Wyszogrodzka
# 495357  ff8fbef897530b901229c204eb46b8a1                 Plac Grzybowski
# 495358  ff90e71b117a22c29d636bdfff8b1bbe      Sosnkowskiego - OSiR Ursus
# 495359  fffeecd35a623278f18627b396a6fde9             Pętla Podskarbińska
#
#          latitude  longitude                          timestamp  free_bikes  \
# 0       52.210833  21.007851  2025-10-19T23:57:33.672212+00:00Z          21
# 1       52.290173  20.950370  2025-10-19T23:57:33.667969+00:00Z          13
# 2       52.239358  21.031136  2025-10-19T23:57:33.697936+00:00Z          27
# 3       52.264210  21.026180  2025-10-19T23:57:33.696712+00:00Z          11
# 4       52.226220  20.996172  2025-10-19T23:57:33.670933+00:00Z          10
# ...           ...        ...                                ...         ...
# 495355  52.231056  21.016738  2025-10-20T23:57:39.393682+00:00Z           1
# 495356  52.288592  21.031009  2025-10-20T23:57:39.396460+00:00Z          23
# 495357  52.235858  21.003731  2025-10-20T23:57:39.345487+00:00Z           4
# 495358  52.186994  20.890648  2025-10-20T23:57:39.395220+00:00Z          12
# 495359  52.254189  21.073601  2025-10-20T23:57:39.344900+00:00Z          15
#
#         empty_slots                   datetime  suma_long_lat
# 0                 0 2025-10-19 23:57:33.672212     178.257939
# 1                 0 2025-10-19 23:57:33.667969     177.992393
# 2                 0 2025-10-19 23:57:33.697936     178.426174
# 3                 0 2025-10-19 23:57:33.696712     178.421290
# 4                 0 2025-10-19 23:57:33.670933     178.203252
# ...             ...                        ...            ...
# 495355            7 2025-10-20 23:57:39.393682     178.331484
# 495356            0 2025-10-20 23:57:39.396460     178.474646
# 495357            8 2025-10-20 23:57:39.345487     178.258244
# 495358            0 2025-10-20 23:57:39.395220     177.530882
# 495359            0 2025-10-20 23:57:39.344900     178.695795
#
# [495360 rows x 9 columns]

# %%
rowery_df['datetime'].hour
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1876\2693923792.py in ?()
# ----> 1 rowery_df['datetime'].hour
#
# ~\Desktop\work\Szkolenie_Comarch\2025_10_20-22\kod\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'hour'
