# %%
import pandas as pd

# %%
df = pd.read_csv("rowery/wynik.csv", sep=',' )
df
# Out:
#                                       id                            name  \
# 0       005de3bbdc044ed97ea20d32ea6401be   al. Niepodległości - Batorego
# 1       013e8c1f7b4782baa326a337d2b00394           Marymoncka - Dewajtis
# 2       029c42156011a06c59bc24773c914cba    Metro Centrum Nauki Kopernik
# 3       02c9feac733886f5bdef0fe682da4b32  Darwina - Nusbauma-Hilarowicza
# 4       037fadcd3c17b99a1cbc687d1d04274d    al. Jerozolimskie - Lindleya
# ...                                  ...                             ...
# 495355  fda32f025901aa9743b1596d43969ab3      al. Jerozolimskie - Krucza
# 495356  feb31a4e8466caf11d6a16addc0b11e1     Rembielińska - Wyszogrodzka
# 495357  ff8fbef897530b901229c204eb46b8a1                 Plac Grzybowski
# 495358  ff90e71b117a22c29d636bdfff8b1bbe      Sosnkowskiego - OSiR Ursus
# 495359  fffeecd35a623278f18627b396a6fde9             Pętla Podskarbińska
#
#          latitude  longitude  free_bikes  empty_slots  \
# ...

# %%
# wybierz kolumny name, free_bikes, empty_slots dla wierszy gdzie hour > 12 i hour <= 14

df[
  (df['hour'] > 12) & (df['hour'] <= 14)
][
    ['name', 'empty_slots', 'free_bikes']
]
# Out:
#                                   name  empty_slots  free_bikes
# 268664   al. Niepodległości - Batorego            4          11
# 268665           Marymoncka - Dewajtis            1           9
# 268666    Metro Centrum Nauki Kopernik            0          28
# 268667  Darwina - Nusbauma-Hilarowicza            4           6
# 268668    al. Jerozolimskie - Lindleya            0          10
# ...                                ...          ...         ...
# 309939      al. Jerozolimskie - Krucza            6           2
# 309940     Rembielińska - Wyszogrodzka            3          18
# 309941                 Plac Grzybowski            6           6
# 309942      Sosnkowskiego - OSiR Ursus            0           9
# 309943             Pętla Podskarbińska            3           2
#
# [41280 rows x 3 columns]

# %%
df.where( (df['hour'] == 23) & (df['name']=='Pętla Podskarbińska') )
# Out:
#                                       id                 name   latitude  \
# 0                                    NaN                  NaN        NaN
# 1                                    NaN                  NaN        NaN
# 2                                    NaN                  NaN        NaN
# 3                                    NaN                  NaN        NaN
# 4                                    NaN                  NaN        NaN
# ...                                  ...                  ...        ...
# 495355                               NaN                  NaN        NaN
# 495356                               NaN                  NaN        NaN
# 495357                               NaN                  NaN        NaN
# 495358                               NaN                  NaN        NaN
# 495359  fffeecd35a623278f18627b396a6fde9  Pętla Podskarbińska  52.254189
#
#         longitude  free_bikes  empty_slots                    datetime  hour
# ...

# %%
df.query("hour == 23 and free_bikes > 10")
# Out:
#                                       id  \
# 0       005de3bbdc044ed97ea20d32ea6401be
# 1       013e8c1f7b4782baa326a337d2b00394
# 2       029c42156011a06c59bc24773c914cba
# 3       02c9feac733886f5bdef0fe682da4b32
# 5       05eded1e34c135651fc9c48505c5f01b
# ...                                  ...
# 495353  fd6f4cfe92505a63f00f233f090766d8
# 495354  fd9388a2cf757555a3b4a0f16bf07c0e
# 495356  feb31a4e8466caf11d6a16addc0b11e1
# 495358  ff90e71b117a22c29d636bdfff8b1bbe
# 495359  fffeecd35a623278f18627b396a6fde9
#
#                                             name   latitude  longitude  \
# 0                  al. Niepodległości - Batorego  52.210833  21.007851
# 1                          Marymoncka - Dewajtis  52.290173  20.950370
# 2                   Metro Centrum Nauki Kopernik  52.239358  21.031136
# 3                 Darwina - Nusbauma-Hilarowicza  52.264210  21.026180
# 5                              Brukselska - PROM  52.225850  21.060062
# ...

# %%
df[
    
    (df['name'].str.lower().str.contains('marszał'))
    & (df['hour'] == 12)
    
    ]
# Out:
#                                       id                               name  \
# 248055  16fcc6f4399c540070064b9465943f74          Marszałkowska - Królewska
# 248088  29f23d1d048ba4a2c2be09a1911e97d8               Marszałkowska - Hoża
# 248094  2dc44d0c649a7b2be8a18866ac754645  Marszałkowska - Al. Jerozolimskie
# 248149  623240d65bdea78c38a81eb3b69de459           Marszałkowska - Litewska
# 248399  16fcc6f4399c540070064b9465943f74          Marszałkowska - Królewska
# ...                                  ...                                ...
# 268101  623240d65bdea78c38a81eb3b69de459           Marszałkowska - Litewska
# 268351  16fcc6f4399c540070064b9465943f74          Marszałkowska - Królewska
# 268384  29f23d1d048ba4a2c2be09a1911e97d8               Marszałkowska - Hoża
# 268390  2dc44d0c649a7b2be8a18866ac754645  Marszałkowska - Al. Jerozolimskie
# 268445  623240d65bdea78c38a81eb3b69de459           Marszałkowska - Litewska
#
#          latitude  longitude  free_bikes  empty_slots  \
# ...

# %%
df2 = pd.read_excel('dane.xlsx')
df2
# Out:
#      imie  wiek     zespol       jezyk
# 0  Michał    32     Północ      Python
# 1   Iryna    36     Wschód        Java
# 2   Jakub    34     Zachód      Pascal
# 3  Tomasz    35   Południe       Basic
# 4   Józek    45    Szaraki           R
# 5   Maria    23  Stokrotki  JavaScript

# %%
df2[ df2['zespol'].isin( ['Północ', 'Zachód']  ) ]
# Out:
#      imie  wiek  zespol   jezyk
# 0  Michał    32  Północ  Python
# 2   Jakub    34  Zachód  Pascal

# %%
df3 = pd.DataFrame([{'imie': 'Jan', 'nazwisko': 'Kowalski', 'wiek': 50, 'zawod': 'miłosny'},
 {'imie': 'Anna', 'nazwisko': 'Nowak', 'wiek': 30},
 {'imie': 'Maria',
  'nazwisko': 'Iksińska',
  'wiek': 45,
  'stan_cywilny': 'panna'},
 {'imie': 'Zofia', 'nazwisko': 'Jakaś', 'wiek': 18}])
df3
# Out:
#     imie  nazwisko  wiek    zawod stan_cywilny
# 0    Jan  Kowalski    50  miłosny          NaN
# 1   Anna     Nowak    30      NaN          NaN
# 2  Maria  Iksińska    45      NaN        panna
# 3  Zofia     Jakaś    18      NaN          NaN

# %%
df3[ df3['stan_cywilny'].isnull() ]
# Out:
#     imie  nazwisko  wiek    zawod stan_cywilny
# 0    Jan  Kowalski    50  miłosny          NaN
# 1   Anna     Nowak    30      NaN          NaN
# 3  Zofia     Jakaś    18      NaN          NaN

# %%
df3[ df3['zawod'].notnull() ]
# Out:
#   imie  nazwisko  wiek    zawod stan_cywilny
# 0  Jan  Kowalski    50  miłosny          NaN

# %%
df.sort_values('free_bikes', ascending=False)
# Out:
#                                       id                                name  \
# 158116  a107ddb793497db8db7ba3ef2fd364a8                Stefana Banacha - UW
# 158460  a107ddb793497db8db7ba3ef2fd364a8                Stefana Banacha - UW
# 157772  a107ddb793497db8db7ba3ef2fd364a8                Stefana Banacha - UW
# 159148  a107ddb793497db8db7ba3ef2fd364a8                Stefana Banacha - UW
# 157428  a107ddb793497db8db7ba3ef2fd364a8                Stefana Banacha - UW
# ...                                  ...                                 ...
# 396409  5e7c15dcd78c0c99867d9b6e70de1c36                 Signum Work Station
# 396513  a60bac12ba693d9c5dbfd690a93de8a7           al. Jana Pawła II - Złota
# 237882  85d89ba1e43191bc23bfc6444736f435  Żwirki i Wigury - Księcia Trojdena
# 362697  5e7c15dcd78c0c99867d9b6e70de1c36                 Signum Work Station
# 362701  623240d65bdea78c38a81eb3b69de459            Marszałkowska - Litewska
#
# ...

# %%
df.sample(n=50).sort_values(['name', 'hour'], ascending=[True, False])
# Out:
#                                       id  \
# 38707   86213faf7aee9deee68aacfd79f115a5
# 254876  ec2793a89a03e214e4228e9083bbd8aa
# 209250  47916561021f038309a2ff07ae5e571c
# 370072  c05c20c0e678da08d8b45e0b8fc191f9
# 463630  ba74d1d1738c89213875333a37282337
# 441958  ba74d1d1738c89213875333a37282337
# 134694  8d62a1eb06b56ca822bf35433f237d3b
# 315210  54d3576924465dff8b76acd630900eb1
# 481425  7ee23f34107eb16fdd879d40eed6575e
# 9864    a9a6d175f9140492e710a63f02566383
# 386822  7ceab6e8efa9ca38f0784ea9c88a18ff
# 160559  b5807ac7cde669faa4acf58062af6cec
# 423400  cd6de284b773ece88533e894c27a3132
# 296433  b0fca3c3664cef01d24093ad3f6750f8
# 471765  68eb27349652ac8eba52ded032faf320
# 464846  4f94bf1152f0a29c803d1bc3e254241e
# 82318   4f94bf1152f0a29c803d1bc3e254241e
# 30726   583f2ee050cff111c982e6272109279b
# 216981  ba7299f75bd03aae54e41a68a8564b9b
# 13583   7d633b3803ab57344b67d98799dbcb62
# 302174  6a25325bdbbcedbfc3295f3de42b5122
# 181573  d02e28bf8ed332ed2bb609634b176cde
# ...
